# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
df=pd.read_csv('D:\MeriSkill\diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df['Pregnancies'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Glucose'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
df['BloodPressure'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Insulin'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Age'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
df['DiabetesPedigreeFunction'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
df['BMI'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
plt.figure(figsize=(20,15))
for i in range(len(df.columns)):
    plt.subplot(4,3,i+1)
    sns.boxplot(x=df.iloc[:,i])
    plt.xlabel(df.columns[i],size=12)

# %%
print(df['Outcome'].value_counts())
plt.figure(figsize=(8, 5))
sns.countplot(x='Outcome', hue= 'Outcome',data=df)
plt.xlabel('Outcome', size=12)
plt.ylabel('Count', size=12)
plt.title('Distribution in target variable', size=12)
plt.show()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
cor=df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(cor,annot=True)
# Out:
# <Axes: >

# %%
sns.lmplot(x='Insulin', y='Pregnancies', hue= 'Outcome', data=df)

# %%
sns.lmplot(x='SkinThickness', y='Pregnancies', hue= 'Outcome', data=df)

# %%
sns.lmplot(x='Insulin', y='Age', hue= 'Outcome', data=df)

# %%
sns.lmplot(x='Insulin', y='BloodPressure', hue= 'Outcome', data=df)

# %%
sns.lmplot(x='SkinThickness', y='Glucose', hue= 'Outcome', data=df)

# %%
sns.lmplot(x='Age', y='Pregnancies', hue= 'Outcome', data=df)
